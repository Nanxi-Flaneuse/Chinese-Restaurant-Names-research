# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import openai
from sentence_transformers import SentenceTransformer, util
import json

# states = ['Alabama', 'Arkansas', 'Kentucky', 'Louisiana', 'Mississippi', 'Tennessee', 'Texas', 'Oklahoma','California', 'Oregon', 'Washington', 'Alaska', 'Hawaii','Arizona', 'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Wyoming','Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin','Pennsylvania', 'Vermont', 'West Virginia','District Of Columbia','Connecticut', 'Delaware', 'Florida', 'Georgia', 'Maine', 'Maryland', 'Massachusetts', 'New Hampshire', 'New Jersey', 'New York', 'North Carolina', 'Rhode Island', 'South Carolina', 'Virginia']
df = pd.read_csv(r'sample_chatGPT.csv')
df_500 = pd.read_csv(r'sample_500.csv')
print(df_500.shape)
print(df_500.sample_id)
# Out:
# (500, 15)
# 0      2094
# 1      1724
# 2      2841
# 3      3119
# 4      1223
#        ...
# 495     862
# 496    2473
# 497    4022
# 498    2324
# 499    1759
# Name: sample_id, Length: 500, dtype: int64

# %%
# print(df.iloc[5])
# print(df.iloc[0])
# print(df)

# %% [markdown]
# ### Sampling

# %%
# Need to filter out non-English characters for the sample
def sample(df,df2):
    # getting rid of duplicates from the previous 500 samples
    df_new = pd.merge(df,df2, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
    df_sample = df_new.sample(n = 500)
    df_sample.to_csv('sample_500_1.csv', index=False, encoding='utf-8')
#     df_new.to_csv('sample_new.csv', index=False, encoding='utf-8')
    return df_sample
sample(df,df_500)
# Out:
#       Unnamed: 0  sample_id  national_id                              name  \
# 1263        1263       2628         2174                       Dragon Gate
# 820          820       1688         2736                     Bamboo Garden
# 731          731       1513         8756              Guan Long Restaurant
# 1916        1916       3945         5338                        China City
# 1215        1215       2548        18373  Hong Kong kitchen(near Westwego)
# ...          ...        ...          ...                               ...
# 1636        1636       3397        28644                      North Garden
# 1905        1905       3929        20751                            Run Da
# 707          707       1470        30298                   Shanghai Bistro
# 177          177        356        16695                      Panda Buffet
# 466          466        953         3399             Red Leaves Restaurant
#
#                                           location_link  \
# 1263  https://www.google.com/maps/place/Dragon+Gate/...
# 820   https://www.google.com/maps/place/Bamboo+Garde...
# 731   https://www.google.com/maps/place/Guan+Long+Re...
# 1916  https://www.google.com/maps/place/China+City/@...
# 1215  https://www.google.com/maps/place/Hong+Kong+ki...
# ...                                                 ...
# 1636  https://www.google.com/maps/place/North+Garden...
# 1905  https://www.google.com/maps/place/Run+Da/@33.1...
# 707   https://www.google.com/maps/place/Shanghai+Bis...
# 177   https://www.google.com/maps/place/Panda+Buffet...
# 466   https://www.google.com/maps/place/Red+Leaves+R...
#
#                                                    site       us_state  \
# 1263                       http://www.dragongatefl.com/        Florida
# 820                      http://www.bamboogardenga.com/        Georgia
# 731                           https://guanlongtogo.com/     New Jersey
# 1916                                                NaN  New Hampshire
# 1215                 http://hongkongkitchenmarrero.com/      Louisiana
# ...                                                 ...            ...
# 1636                                                NaN        Indiana
# 1905  https://www.beyondmenu.com/40381/mckinney/run-...          Texas
# 707                            http://shbistro.com/menu      Wisconsin
# 177                                                 NaN           Utah
# 466              https://www.redleavesnorthberwick.com/          Maine
#
#                     type                                           subtypes  \
# 1263  Chinese restaurant  Chinese restaurant, Delivery Restaurant, Resta...
# 820   Chinese restaurant                                 Chinese restaurant
# 731   Chinese restaurant            Chinese restaurant, Delivery Restaurant
# 1916  Chinese restaurant                                 Chinese restaurant
# 1215  Chinese restaurant                                 Chinese restaurant
# ...                  ...                                                ...
# 1636  Chinese restaurant                                 Chinese restaurant
# 1905  Chinese restaurant                     Chinese restaurant, Restaurant
# 707   Chinese restaurant  Chinese restaurant, Bar, Asian restaurant, Glu...
# 177   Chinese restaurant                                 Chinese restaurant
# 466   Chinese restaurant                                 Chinese restaurant
#
#       Area  rating  has_name CH_name  \
# 1263     2     4.1         1      龙苑
# 820      1     3.1         1      竹园
# 731      2     4.2         1      冠龙
# 1916     2     3.1         1     中国城
# 1215     2     4.4         1      香港
# ...    ...     ...       ...     ...
# 1636     2     3.7         1      北园
# 1905     1     4.1         1     红灯笼
# 707      2     4.3         1      上海
# 177      1     4.0         1      满圆
# 466      0     3.8         1      红叶
#
#                                                  source chatGPT_translations
# 1263  https://www.google.com/maps/place/Dragon+Gate/...        Dragon Garden
# 820                     https://www.bamboogardenga.com/        Bamboo Garden
# 731   https://www.google.com/maps/place/Guan+Long+Re...         Crown Dragon
# 1916  https://www.google.com/maps/place/China+City/@...           China Town
# 1215  https://www.google.com/maps/place/Hong+Kong+ki...            Hong Kong
# ...                                                 ...                  ...
# 1636  https://www.google.com/maps/place/North+Garden...         North Garden
# 1905  https://www.google.com/maps/place/Run+Da/@33.1...          Red Lantern
# 707   https://www.google.com/maps/place/Shanghai+Bis...             Shanghai
# 177   https://www.google.com/maps/place/Panda+Garden...          Full Circle
# 466   https://www.google.com/maps/place/Red+Leaves+R...             Red Leaf
#
# [500 rows x 15 columns]
