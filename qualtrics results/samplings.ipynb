# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# import openai
# from sentence_transformers import SentenceTransformer, util
import json

# states = ['Alabama', 'Arkansas', 'Kentucky', 'Louisiana', 'Mississippi', 'Tennessee', 'Texas', 'Oklahoma','California', 'Oregon', 'Washington', 'Alaska', 'Hawaii','Arizona', 'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Wyoming','Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin','Pennsylvania', 'Vermont', 'West Virginia','District Of Columbia','Connecticut', 'Delaware', 'Florida', 'Georgia', 'Maine', 'Maryland', 'Massachusetts', 'New Hampshire', 'New Jersey', 'New York', 'North Carolina', 'Rhode Island', 'South Carolina', 'Virginia']
df = pd.read_csv(r'sample_chatGPT.csv')
df_500 = pd.read_csv(r'sample_500.csv')
df_500_1 = pd.read_csv(r'sample_500_1.csv')
# print(df_500.shape)
# print(df_500.sample_id)
# print(df_500_1.shape)
# print(df_500_1.sample_id)
df_1000 = pd.concat([df_500,df_500_1])
print(df_1000)
# Out:
#      Unnamed: 0  sample_id  national_id                   name  \
# 0          1012       2094         9870           Little Alley
# 1           839       1724        13697       New China Buffet
# 2          1362       2841        28810                 MImian
# 3          1500       3119         9756          Bamboo Garden
# 4           600       1223        29370             China Cafe
# ..          ...        ...          ...                    ...
# 495        1636       3397        28644           North Garden
# 496        1905       3929        20751                 Run Da
# 497         707       1470        30298        Shanghai Bistro
# 498         177        356        16695           Panda Buffet
# 499         466        953         3399  Red Leaves Restaurant
#
#                                          location_link  \
# 0    https://www.google.com/maps/place/Little+Alley...
# 1    https://www.google.com/maps/place/New+China+Bu...
# ...

# %%
# print(df.iloc[5])
# print(df.iloc[0])
# print(df)

# %% [markdown]
# ### Sampling

# %%
# Need to filter out non-English characters for the sample
def sample(df,df2):
    # getting rid of duplicates from the previous 500 samples
    df_new = pd.merge(df,df2, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
    df_sample = df_new.sample(n = 500)
    df_sample.to_csv('sample_500_1.csv', index=False, encoding='utf-8')
#     df_new.to_csv('sample_new.csv', index=False, encoding='utf-8')
    return df_sample
# sample(df,df_500)
df_new = pd.merge(df,df_1000, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
print(df_new)
df_new.to_csv('../model_training/remaining_1000_datapoints.csv', index=False, encoding='utf-8')
# Out:
#       Unnamed: 0  sample_id  national_id                           name  \
# 1              1          7        14762  Cheung Wah Chinese Restaurant
# 3              3         11        24644            Hong Kong Fast Food
# 6              6         22         7336         Great Taste Restaurant
# 7              7         23        12499                      Shun Xing
# 9              9         25        22001         JS Foothill Restaurant
# ...          ...        ...          ...                            ...
# 1944        1944       4003         2856                     China King
# 1945        1945       4005        21030                   Xinjiang BBQ
# 1947        1947       4016        24538                     Bamboo Inn
# 1954        1954       4027        22531    Fook Lam Seafood Restaurant
# 1955        1955       4028        16969             Sichuanese Cuisine
#
#                                           location_link  \
# ...
